# %%
from data_import import data_to_dictionary, create_parameters
from sir import Sir
import matplotlib
# Out:
# /Users/florawang/.pyenv/versions/python3.8/lib/python3.8/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
parsed_data = data_to_dictionary("../../../Simulator - Test Sheet - Sample Data.csv")
parameters = create_parameters(parsed_data[0])
#print(parameters.doubling_time)
sir = Sir(parameters)
# Out:
# 2020-06-09 15:28:18,964 - sir - INFO - Using doubling_time: 5
# 2020-06-09 15:28:19,204 - sir - INFO - Estimated date_first_hospitalized: 2020-06-06; current_date: 2020-06-09; i_day: 3
# 2020-06-09 15:28:19,211 - sir - INFO - len(np.arange(-i_day, n_days+1)): 34
# 2020-06-09 15:28:19,212 - sir - INFO - len(raw_df): 34

# %%
sir.raw_df
# Out:
#     day   susceptible    infected    recovered  ever_infected  \
# 0    -3  3.271672e+08  266.666667     1.000000     267.666667
# 1    -2  3.271671e+08  248.475759    89.888889     338.364648
# 2    -1  3.271670e+08  231.525746   172.714142     404.239888
# 3     0  3.271670e+08  215.731982   249.889390     465.621372
# 4     1  3.271669e+08  201.015595   321.800051     522.815646
# 5     2  3.271669e+08  187.303093   388.805249     576.108342
# 6     3  3.271668e+08  174.525996   451.239614     625.765610
# 7     4  3.271668e+08  162.620497   509.414946     672.035442
# 8     5  3.271667e+08  151.527139   563.621778     715.148917
# 9     6  3.271667e+08  141.190523   614.130824     755.321347
# 10    7  3.271666e+08  131.559028   661.194332     792.753360
# 11    8  3.271666e+08  122.584554   705.047341     827.631895
# 12    9  3.271666e+08  114.222282   745.908859     860.131142
# 13   10  3.271665e+08  106.430451   783.982953     890.413404
# ...

# %%
sir.raw_df.ever_infected - sir.raw_df.infected - sir.raw_df.recovered
# Out:
# 0     0.000000e+00
# 1     2.842171e-14
# 2     0.000000e+00
# 3     0.000000e+00
# 4    -5.684342e-14
# 5     0.000000e+00
# 6     5.684342e-14
# 7     0.000000e+00
# 8     0.000000e+00
# 9     0.000000e+00
# 10    0.000000e+00
# 11    0.000000e+00
# 12    0.000000e+00
# 13    0.000000e+00
# 14    0.000000e+00
# 15    0.000000e+00
# 16    0.000000e+00
# 17    0.000000e+00
# 18    0.000000e+00
# 19    1.136868e-13
# 20    0.000000e+00
# 21   -1.136868e-13
# 22    0.000000e+00
# 23    0.000000e+00
# 24    0.000000e+00
# 25    0.000000e+00
# 26    0.000000e+00
# 27    0.000000e+00
# 28    0.000000e+00
# 29    0.000000e+00
# 30    0.000000e+00
# 31    0.000000e+00
# 32    0.000000e+00
# 33    0.000000e+00
# dtype: float64

# %%
sir.raw_df.plot('date','census_ventilated')

# %%
from data_import import data_to_dictionary, create_parameters
from sir import Sir
import matplotlib

# %%
parsed_data = data_to_dictionary("sample_data_default.csv")
parameters = create_parameters(parsed_data[0])
#print(parameters.doubling_time)
sir = Sir(parameters)
# Out:
# 2020-05-31 21:36:54,838 - sir - INFO - Using doubling_time: 5
# 2020-05-31 21:36:55,221 - sir - INFO - Estimated date_first_hospitalized: 2020-04-25; current_date: 2020-05-31; i_day: 36
# 2020-05-31 21:36:55,258 - sir - INFO - len(np.arange(-i_day, n_days+1)): 67
# 2020-05-31 21:36:55,260 - sir - INFO - len(raw_df): 67

# %%
sir.raw_df
# Out:
#     day   susceptible      infected      recovered  ever_infected  \
# 0   -36  3.599733e+06    266.666667       1.000000     267.666667
# 1   -35  3.599667e+06    306.319561      27.666667     333.986228
# 2   -34  3.599591e+06    351.867373      58.298623     410.165995
# 3   -33  3.599503e+06    404.186008      93.485360     497.671368
# 4   -32  3.599403e+06    464.281380     133.903961     598.185341
# ..  ...           ...           ...            ...            ...
# 62   26  3.443930e+06  48893.204065  107177.720382  156070.924446
# 63   27  3.437532e+06  50402.235175  112067.040788  162469.275963
# 64   28  3.430948e+06  51945.586603  117107.264306  169052.850909
# 65   29  3.424176e+06  53523.201540  122301.822966  175825.024506
# 66   30  3.417212e+06  55134.956259  127654.143120  182789.099378
#
#     ever_hospitalized  hospitalized    ever_icu       icu  ever_ventilated  \
# 0            1.003750           NaN    0.301125       NaN         0.200750
# 1            1.252448      0.248698    0.375735  0.074610         0.250490
# 2            1.538122      0.285674    0.461437  0.085702         0.307624
# 3            1.866268      0.328145    0.559880  0.098444         0.373254
# 4            2.243195      0.376927    0.672959  0.113078         0.448639
# ..                ...           ...         ...       ...              ...
# 62         585.265967     23.312121  175.579790  6.993636       117.053193
# 63         609.259785     23.993818  182.777935  7.198145       121.851957
# 64         633.948191     24.688406  190.184457  7.406522       126.789638
# 65         659.343842     25.395651  197.803153  7.618695       131.868768
# 66         685.459123     26.115281  205.637737  7.834584       137.091825
#
#     ventilated  admits_hospitalized  admits_icu  admits_ventilated  \
# 0          NaN                  NaN         NaN                NaN
# 1     0.049740             0.248698    0.074610           0.049740
# 2     0.057135             0.285674    0.085702           0.057135
# 3     0.065629             0.328145    0.098444           0.065629
# 4     0.075385             0.376927    0.113078           0.075385
# ..         ...                  ...         ...                ...
# 62    4.662424            23.312121    6.993636           4.662424
# 63    4.798764            23.993818    7.198145           4.798764
# 64    4.937681            24.688406    7.406522           4.937681
# 65    5.079130            25.395651    7.618695           5.079130
# 66    5.223056            26.115281    7.834584           5.223056
#
#     census_hospitalized  census_icu  census_ventilated       date
# 0              0.000000    0.000000           0.000000 2020-04-25
# 1              0.248698    0.074610           0.049740 2020-04-26
# 2              0.534372    0.160312           0.106874 2020-04-27
# 3              0.862518    0.258755           0.172504 2020-04-28
# 4              1.239445    0.371834           0.247889 2020-04-29
# ..                  ...         ...                ...        ...
# 62           149.611567   56.059287          40.928568 2020-06-26
# 63           154.104100   57.755659          42.171622 2020-06-27
# 64           158.689825   59.488137          43.441454 2020-06-28
# 65           163.367823   61.256447          44.737889 2020-06-29
# 66           168.136938   63.060227          46.060688 2020-06-30
#
# [67 rows x 18 columns]

# %%
sir.raw_df.ever_infected - sir.raw_df.infected - sir.raw_df.recovered
# Out:
# 0     0.000000e+00
# 1     1.421085e-14
# 2     2.131628e-14
# 3    -1.421085e-14
# 4     0.000000e+00
#           ...
# 62    0.000000e+00
# 63    0.000000e+00
# 64   -1.455192e-11
# 65    1.455192e-11
# 66    0.000000e+00
# Length: 67, dtype: float64

# %%
sir.raw_df.plot('date','census_ventilated')
# Out:
# 2020-05-31 21:54:37,833 - matplotlib.font_manager - INFO - Failed to extract font properties from /System/Library/Fonts/Apple Color Emoji.ttc: In FT2Font: Could not set the fontsize (error code 0x17)
# 2020-05-31 21:54:38,631 - matplotlib.font_manager - INFO - Failed to extract font properties from /System/Library/Fonts/Supplemental/NISC18030.ttf: In FT2Font: Could not set the fontsize (error code 0x17)
# 2020-05-31 21:54:39,663 - matplotlib.font_manager - INFO - generated new fontManager
